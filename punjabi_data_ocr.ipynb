# %% [markdown]
# <a href="https://colab.research.google.com/github/GurnoorKaur-30/internship-project_Gurnoor/blob/main/punjabi_data_ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install -y tesseract-ocr tesseract-ocr-pan tesseract-ocr-eng poppler-utils -qq
# !tesseract --list-langs
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../libpoppler-private-dev_22.02.0-2ubuntu0.13_amd64.deb ...
# Unpacking libpoppler-private-dev:amd64 (22.02.0-2ubuntu0.13) over (22.02.0-2ubuntu0.12) ...
# Preparing to unpack .../libpoppler-dev_22.02.0-2ubuntu0.13_amd64.deb ...
# Unpacking libpoppler-dev:amd64 (22.02.0-2ubuntu0.13) over (22.02.0-2ubuntu0.12) ...
# Preparing to unpack .../libpoppler118_22.02.0-2ubuntu0.13_amd64.deb ...
# Unpacking libpoppler118:amd64 (22.02.0-2ubuntu0.13) over (22.02.0-2ubuntu0.12) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.13_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.13) ...
# ...

# %%
# !pip install docling pymupdf openpyxl huggingface_hub -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.6/648.6 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.7/25.7 MB 86.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.9/279.9 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 95.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>LHO5-I873</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>Gurnoor-Kaur30</b> (token: <code>oauth-Gurnoor-Kaur30</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !pip install hf_transfer -q
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 37.9 MB/s eta 0:00:00

# %%
from huggingface_hub import snapshot_download

local_path = snapshot_download(
    repo_id="Arshii/IMD_2025_SOND",
    repo_type="dataset",
    local_dir="/content/pdfs",
    allow_patterns=[
        "*/Punjab/*.pdf",
        "*/Punjab/**/*.pdf",
    ],
)
print(f"Downloaded to: {local_path}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:298: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# ...
# Fetching ... files: 0it [00:00, ?it/s]
# Downloaded to: /content/pdfs

# %%
import os
os.environ["HF_XET_HIGH_PERFORMANCE"] = "1"

from huggingface_hub import snapshot_download

local_path = snapshot_download(
    repo_id="Arshii/IMD_2025_SOND",
    repo_type="dataset",
    local_dir="/content/pdfs",
    allow_patterns=[
        "*/Punjab/*.pdf",
        "*/Punjab/**/*.pdf",
    ],
)
print(f"Downloaded to: {local_path}")
# Out:
# ...
# Fetching ... files: 0it [00:00, ?it/s]
# Downloaded to: /content/pdfs

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f828a5af-ecc2-46f6-b44a-c0d82a9b0765" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f828a5af-ecc2-46f6-b44a-c0d82a9b0765">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(f"CPU cores available: {os.cpu_count()}")
# Out:
# CPU cores available: 2

# %%
# !python local_ocr_pipeline_parallel.py \
  --input_dir "/content/pdfs/2025_Local_Data_Async_Sept_Oct_Nov_Dec/Punjab" \
  --output_dir "/content/drive/MyDrive/ocr_output/punjabi_output" \
  --tesseract_cmd "tesseract" \
  --force_full_ocr
# Out:
# Streaming output truncated to the last 5000 lines.
# 2026-07-13 07:15:34,919 [INFO] Finished converting document 2025-10-24.pdf in 24.67 sec.
# 2026-07-13 07:15:34,936 [INFO] [84/622] OK: Bhatinda/October/2025-10-24.pdf
# 2026-07-13 07:15:34,937 [INFO] detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-07-13 07:15:34,940 [INFO] Going to convert document batch...
# 2026-07-13 07:15:34,940 [INFO] Processing document 2025-10-28.pdf
# 2026-07-13 07:15:35,720 [INFO] command: tesseract --psm 0 -l osd /tmp/tmp02k0cvu4.png stdout
# 2026-07-13 07:15:37,184 [INFO] command: tesseract -l eng+pan /tmp/tmp02k0cvu4.png stdout tsv
# 2026-07-13 07:15:44,299 [INFO] command: tesseract --psm 0 -l osd /tmp/tmpyytop9yc.png stdout
# 2026-07-13 07:15:46,026 [INFO] command: tesseract -l eng+pan /tmp/tmpyytop9yc.png stdout tsv
# 2026-07-13 07:15:56,755 [INFO] command: tesseract --psm 0 -l osd /tmp/tmp95wvbegv.png stdout
# ...
